# %%
# Use Google Colab
use_colab = True

# Is this notebook running on Colab?
# If so, then google.colab package (github.com/googlecolab/colabtools)
# should be available in this environment

# Previous version used importlib, but we could do the same thing with
# just attempting to import google.colab
try:
    from google.colab import drive
    colab_available = True
except:
    colab_available = False

if use_colab and colab_available:
    drive.mount('/content/drive')

    # cd to the appropriate working directory under my Google Drive
    # %cd '/content/drive/My Drive/cs696ds_lexalytics/Ronald Gypsum Prompts'
    
    # Install packages specified in requirements
    # !pip install -r requirements.txt

    # %cd 'prompts_subtask4'
    
    # List the directory contents
    # !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/cs696ds_lexalytics/Ronald Gypsum Prompts
# Requirement already satisfied: transformers==4.3.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 1)) (4.3.3)
# Requirement already satisfied: datasets==1.2.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 2)) (1.2.1)
# Requirement already satisfied: pytokenizations==0.7.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 3)) (0.7.2)
# Requirement already satisfied: spacy==2.3.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 4)) (2.3.5)
# Requirement already satisfied: en_core_web_sm from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz#egg=en_core_web_sm in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 5)) (2.2.5)
# Requirement already satisfied: scikit-learn==0.24.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 6)) (0.24.1)
# Requirement already satisfied: torch==1.7.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 7)) (1.7.1)
# Requirement already satisfied: papermill==2.3.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 8)) (2.3.2)
# Requirement already satisfied: jupyter-client==6.1.7 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 9)) (6.1.7)
# Requirement already satisfied: ipython==7.21.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 10)) (7.21.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3->-r requirements.txt (line 1)) (1.19.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3->-r requirements.txt (line 1)) (4.41.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3->-r requirements.txt (line 1)) (2019.12.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3->-r requirements.txt (line 1)) (2.23.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3->-r requirements.txt (line 1)) (0.0.45)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3->-r requirements.txt (line 1)) (3.0.12)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3->-r requirements.txt (line 1)) (20.9)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3->-r requirements.txt (line 1)) (3.10.1)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3->-r requirements.txt (line 1)) (0.10.2)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets==1.2.1->-r requirements.txt (line 2)) (0.70.11.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets==1.2.1->-r requirements.txt (line 2)) (0.3.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets==1.2.1->-r requirements.txt (line 2)) (1.1.5)
# Requirement already satisfied: pyarrow>=0.17.1 in /usr/local/lib/python3.7/dist-packages (from datasets==1.2.1->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets==1.2.1->-r requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5->-r requirements.txt (line 4)) (1.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5->-r requirements.txt (line 4)) (3.0.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5->-r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5->-r requirements.txt (line 4)) (7.4.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5->-r requirements.txt (line 4)) (2.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5->-r requirements.txt (line 4)) (0.8.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5->-r requirements.txt (line 4)) (56.1.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5->-r requirements.txt (line 4)) (0.4.1)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5->-r requirements.txt (line 4)) (1.1.3)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5->-r requirements.txt (line 4)) (1.0.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.24.1->-r requirements.txt (line 6)) (1.0.1)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.24.1->-r requirements.txt (line 6)) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.24.1->-r requirements.txt (line 6)) (2.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.7.1->-r requirements.txt (line 7)) (3.7.4.3)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.7/dist-packages (from papermill==2.3.2->-r requirements.txt (line 8)) (7.0.0)
# Requirement already satisfied: nbclient>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from papermill==2.3.2->-r requirements.txt (line 8)) (0.5.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from papermill==2.3.2->-r requirements.txt (line 8)) (0.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from papermill==2.3.2->-r requirements.txt (line 8)) (3.13)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from papermill==2.3.2->-r requirements.txt (line 8)) (7.1.2)
# Requirement already satisfied: nbformat>=5.1.2 in /usr/local/lib/python3.7/dist-packages (from papermill==2.3.2->-r requirements.txt (line 8)) (5.1.3)
# Requirement already satisfied: black in /usr/local/lib/python3.7/dist-packages (from papermill==2.3.2->-r requirements.txt (line 8)) (21.5b0)
# Requirement already satisfied: ansiwrap in /usr/local/lib/python3.7/dist-packages (from papermill==2.3.2->-r requirements.txt (line 8)) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from jupyter-client==6.1.7->-r requirements.txt (line 9)) (2.8.1)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.7/dist-packages (from jupyter-client==6.1.7->-r requirements.txt (line 9)) (5.0.5)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client==6.1.7->-r requirements.txt (line 9)) (22.0.3)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from jupyter-client==6.1.7->-r requirements.txt (line 9)) (4.7.1)
# Requirement already satisfied: tornado>=4.1 in /usr/local/lib/python3.7/dist-packages (from jupyter-client==6.1.7->-r requirements.txt (line 9)) (5.1.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython==7.21.0->-r requirements.txt (line 10)) (0.7.5)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /usr/local/lib/python3.7/dist-packages (from ipython==7.21.0->-r requirements.txt (line 10)) (4.8.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython==7.21.0->-r requirements.txt (line 10)) (2.6.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython==7.21.0->-r requirements.txt (line 10)) (3.0.18)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython==7.21.0->-r requirements.txt (line 10)) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.7/dist-packages (from ipython==7.21.0->-r requirements.txt (line 10)) (0.18.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython==7.21.0->-r requirements.txt (line 10)) (4.4.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.3.3->-r requirements.txt (line 1)) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.3.3->-r requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.3.3->-r requirements.txt (line 1)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.3.3->-r requirements.txt (line 1)) (2020.12.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.3.3->-r requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==4.3.3->-r requirements.txt (line 1)) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers==4.3.3->-r requirements.txt (line 1)) (3.4.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets==1.2.1->-r requirements.txt (line 2)) (2018.9)
# Requirement already satisfied: async-generator in /usr/local/lib/python3.7/dist-packages (from nbclient>=0.2.0->papermill==2.3.2->-r requirements.txt (line 8)) (1.10)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.7/dist-packages (from nbclient>=0.2.0->papermill==2.3.2->-r requirements.txt (line 8)) (1.5.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from nbformat>=5.1.2->papermill==2.3.2->-r requirements.txt (line 8)) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.7/dist-packages (from nbformat>=5.1.2->papermill==2.3.2->-r requirements.txt (line 8)) (2.6.0)
# Requirement already satisfied: pathspec<1,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from black->papermill==2.3.2->-r requirements.txt (line 8)) (0.8.1)
# Requirement already satisfied: typed-ast>=1.4.2; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from black->papermill==2.3.2->-r requirements.txt (line 8)) (1.4.3)
# Requirement already satisfied: toml>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from black->papermill==2.3.2->-r requirements.txt (line 8)) (0.10.2)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.7/dist-packages (from black->papermill==2.3.2->-r requirements.txt (line 8)) (1.4.4)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.7/dist-packages (from black->papermill==2.3.2->-r requirements.txt (line 8)) (0.4.3)
# Requirement already satisfied: textwrap3>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from ansiwrap->papermill==2.3.2->-r requirements.txt (line 8)) (0.9.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect>4.3; sys_platform != "win32"->ipython==7.21.0->-r requirements.txt (line 10)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython==7.21.0->-r requirements.txt (line 10)) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.16->ipython==7.21.0->-r requirements.txt (line 10)) (0.8.2)
# /content/drive/My Drive/cs696ds_lexalytics/Ronald Gypsum Prompts/prompts_subtask4
# bert_no_prompt_cls_lr_subtask4.ipynb
# bert_no_prompt_pooled_lr_subtask4.ipynb
# bert_prompt_lr_subtask4.ipynb
# bert_zero_shot_prompt_logit_softmax_subtask4.ipynb
# collect_results_snippet.ipynb
# papermill_launcher_no_prompt_cls_lr.ipynb
# papermill_launcher_no_prompt_pooled_lr.ipynb
# papermill_launcher_prompt_logit_softmax.ipynb
# papermill_launcher_prompt_lr.ipynb
# results_bert_16_shot_no_prompt_cls_lr_atsc_restaurants
# results_bert_16_shot_no_prompt_pooled_lr_atsc_restaurants
# results_bert_16_shot_prompt_logit_softmax_atsc_restaurants
# results_bert_16_shot_prompt_lr_concatenate_atsc_restaurants
# results_bert_64_shot_no_prompt_cls_lr_atsc_restaurants
# results_bert_64_shot_prompt_lr_concatenate_atsc_restaurants
# results_bert_no_prompt_cls_lr_atsc_restaurants
# results_bert_prompt_lr_atsc_restaurants
# results_bert_prompt_lr_concatenate_atsc_restaurants

# %%
import os
import itertools

import papermill
import tqdm

# %%
# experiment id prefix
experiment_id_prefix = 'bert_no_prompt_cls_lr_subtask4'

# Random seed
random_seeds = [696, 685, 683, 682, 589]

# path to pretrained MLM model folder or the string "bert-base-uncased"
lm_model_paths = {
    'bert_yelp_restaurants': '../trained_models/lm_further_pretraining_bert_yelp_restaurants_bseoh_2021-03-22--15_03_31',
    'bert-base-uncased': 'bert-base-uncased'
}

# Training settings
training_domain = 'restaurants' # 'laptops', 'restaurants', 'joint'

# Few-shot dataset size
training_dataset_few_shot_size = 1024

if training_dataset_few_shot_size == -1:
    experiment_id_prefix_override = 'bert_no_prompt_cls_lr_atsc'
else:
    experiment_id_prefix_override = 'bert_' + str(training_dataset_few_shot_size) + '_shot_' + 'no_prompt_cls_lr_atsc'

# Test settings
testing_batch_size = 32
testing_domain = 'restaurants'

if testing_domain != training_domain:
    cross_domain = True
else:
    cross_domain = False

# Results directory path
results_path = 'results_' + experiment_id_prefix_override + '_' + testing_domain
os.makedirs(results_path, exist_ok=True)

# %%
for seed, lm_model_name in tqdm.tqdm(itertools.product(random_seeds, lm_model_paths.keys())):
    
    # We will use the following string ID to identify this particular (training) experiments
    # in directory paths and other settings
    experiment_id = experiment_id_prefix_override + '_'
    experiment_id = experiment_id + testing_domain + '_'
    
    if cross_domain:
        experiment_id = experiment_id + 'cross_domain_'

    experiment_id = experiment_id + lm_model_name + '_'
    experiment_id = experiment_id + str(seed)
    
    print("Running experiment", experiment_id)
    print()
    
    parameters_to_inject = {
        'experiment_id': experiment_id,
        'random_seed': seed,
        'lm_model_path': lm_model_paths[lm_model_name],
        #'training_domain': training_domain,
        #'training_dataset_few_shot_size': training_dataset_few_shot_size,
        'testing_batch_size': testing_batch_size,
        'testing_domain': testing_domain
    }

    papermill.execute_notebook(
        os.path.join(experiment_id_prefix + '.ipynb'),
        os.path.join(results_path, experiment_id + '.ipynb'),
        parameters=parameters_to_inject,
        log_output=True,
        progress_bar=True,
        autosave_cell_every=300,
        cwd=os.getcwd(),
    )
# Out:
# 0it [00:00, ?it/s]
# Running experiment bert_1024_shot_no_prompt_cls_lr_atsc_restaurants_bert_yelp_restaurants_696
# Executing:   0%|          | 0/31 [00:00<?, ?cell/s]
# Intel(R) oneAPI Data Analytics Library solvers for sklearn enabled: https://intelpython.github.io/daal4py/sklearn.html
#
# Reusing dataset sem_eval2014_task4_dataset (../dataset_cache/sem_eval2014_task4_dataset/SemEval2014Task4Dataset - Subtask 4/0.0.1/537edd3b5fdbdb1f3190419cf0a53a4fab3537bc666f17c8c75fa8d0b554e529)
#
# 1it [00:40, 40.29s/it]
# Running experiment bert_1024_shot_no_prompt_cls_lr_atsc_restaurants_bert-base-uncased_696
# Executing:   0%|          | 0/31 [00:00<?, ?cell/s]
# Intel(R) oneAPI Data Analytics Library solvers for sklearn enabled: https://intelpython.github.io/daal4py/sklearn.html
#
# Reusing dataset sem_eval2014_task4_dataset (../dataset_cache/sem_eval2014_task4_dataset/SemEval2014Task4Dataset - Subtask 4/0.0.1/537edd3b5fdbdb1f3190419cf0a53a4fab3537bc666f17c8c75fa8d0b554e529)
#
# 2it [01:18, 39.12s/it]
# Running experiment bert_1024_shot_no_prompt_cls_lr_atsc_restaurants_bert_yelp_restaurants_685
# Executing:   0%|          | 0/31 [00:00<?, ?cell/s]
# Intel(R) oneAPI Data Analytics Library solvers for sklearn enabled: https://intelpython.github.io/daal4py/sklearn.html
#
# Reusing dataset sem_eval2014_task4_dataset (../dataset_cache/sem_eval2014_task4_dataset/SemEval2014Task4Dataset - Subtask 4/0.0.1/537edd3b5fdbdb1f3190419cf0a53a4fab3537bc666f17c8c75fa8d0b554e529)
#
# 3it [01:58, 39.64s/it]
# Running experiment bert_1024_shot_no_prompt_cls_lr_atsc_restaurants_bert-base-uncased_685
# Executing:   0%|          | 0/31 [00:00<?, ?cell/s]
# Intel(R) oneAPI Data Analytics Library solvers for sklearn enabled: https://intelpython.github.io/daal4py/sklearn.html
#
# Reusing dataset sem_eval2014_task4_dataset (../dataset_cache/sem_eval2014_task4_dataset/SemEval2014Task4Dataset - Subtask 4/0.0.1/537edd3b5fdbdb1f3190419cf0a53a4fab3537bc666f17c8c75fa8d0b554e529)
#
# 4it [02:36, 38.68s/it]
# Running experiment bert_1024_shot_no_prompt_cls_lr_atsc_restaurants_bert_yelp_restaurants_683
# Executing:   0%|          | 0/31 [00:00<?, ?cell/s]
# Intel(R) oneAPI Data Analytics Library solvers for sklearn enabled: https://intelpython.github.io/daal4py/sklearn.html
#
# Reusing dataset sem_eval2014_task4_dataset (../dataset_cache/sem_eval2014_task4_dataset/SemEval2014Task4Dataset - Subtask 4/0.0.1/537edd3b5fdbdb1f3190419cf0a53a4fab3537bc666f17c8c75fa8d0b554e529)
#
# 5it [03:24, 42.14s/it]
# Running experiment bert_1024_shot_no_prompt_cls_lr_atsc_restaurants_bert-base-uncased_683
# Executing:   0%|          | 0/31 [00:00<?, ?cell/s]
# Intel(R) oneAPI Data Analytics Library solvers for sklearn enabled: https://intelpython.github.io/daal4py/sklearn.html
#
# Reusing dataset sem_eval2014_task4_dataset (../dataset_cache/sem_eval2014_task4_dataset/SemEval2014Task4Dataset - Subtask 4/0.0.1/537edd3b5fdbdb1f3190419cf0a53a4fab3537bc666f17c8c75fa8d0b554e529)
#
# 6it [04:05, 41.84s/it]
# Running experiment bert_1024_shot_no_prompt_cls_lr_atsc_restaurants_bert_yelp_restaurants_682
# Executing:   0%|          | 0/31 [00:00<?, ?cell/s]
# Intel(R) oneAPI Data Analytics Library solvers for sklearn enabled: https://intelpython.github.io/daal4py/sklearn.html
#
# Reusing dataset sem_eval2014_task4_dataset (../dataset_cache/sem_eval2014_task4_dataset/SemEval2014Task4Dataset - Subtask 4/0.0.1/537edd3b5fdbdb1f3190419cf0a53a4fab3537bc666f17c8c75fa8d0b554e529)
#
# 7it [04:50, 42.95s/it]
# Running experiment bert_1024_shot_no_prompt_cls_lr_atsc_restaurants_bert-base-uncased_682
# Executing:   0%|          | 0/31 [00:00<?, ?cell/s]
# Intel(R) oneAPI Data Analytics Library solvers for sklearn enabled: https://intelpython.github.io/daal4py/sklearn.html
#
# Reusing dataset sem_eval2014_task4_dataset (../dataset_cache/sem_eval2014_task4_dataset/SemEval2014Task4Dataset - Subtask 4/0.0.1/537edd3b5fdbdb1f3190419cf0a53a4fab3537bc666f17c8c75fa8d0b554e529)
#
# 8it [05:30, 41.77s/it]
# Running experiment bert_1024_shot_no_prompt_cls_lr_atsc_restaurants_bert_yelp_restaurants_589
# Executing:   0%|          | 0/31 [00:00<?, ?cell/s]
# Intel(R) oneAPI Data Analytics Library solvers for sklearn enabled: https://intelpython.github.io/daal4py/sklearn.html
#
# Reusing dataset sem_eval2014_task4_dataset (../dataset_cache/sem_eval2014_task4_dataset/SemEval2014Task4Dataset - Subtask 4/0.0.1/537edd3b5fdbdb1f3190419cf0a53a4fab3537bc666f17c8c75fa8d0b554e529)
#
# 9it [06:35, 49.13s/it]
# Running experiment bert_1024_shot_no_prompt_cls_lr_atsc_restaurants_bert-base-uncased_589
# Executing:   0%|          | 0/31 [00:00<?, ?cell/s]
# Intel(R) oneAPI Data Analytics Library solvers for sklearn enabled: https://intelpython.github.io/daal4py/sklearn.html
#
# Reusing dataset sem_eval2014_task4_dataset (../dataset_cache/sem_eval2014_task4_dataset/SemEval2014Task4Dataset - Subtask 4/0.0.1/537edd3b5fdbdb1f3190419cf0a53a4fab3537bc666f17c8c75fa8d0b554e529)
#
# 10it [07:13, 43.36s/it]
